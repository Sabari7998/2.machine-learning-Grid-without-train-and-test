# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'max_features':['sqrt', 'log2'], 'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
result=grid.cv_results_
print("The R_score valueforbestparameter{}:".format(grid.best_params_))
# Out:
# The R_score valueforbestparameter{'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(result) 
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.067615      0.006788         0.007667        0.002349
# 1        0.554424      0.022439         0.022284        0.001357
# 2        0.067421      0.005093         0.009042        0.004863
# 3        0.579193      0.005935         0.020204        0.002661
# 4        0.060477      0.001021         0.006950        0.002735
# 5        0.719397      0.140042         0.027071        0.008528
# 6        0.098753      0.047357         0.008288        0.004383
# 7        0.700045      0.046584         0.030504        0.006197
# 8        0.191667      0.014847         0.005540        0.003994
# 9        1.705952      0.026907         0.020504        0.004341
# 10       0.168968      0.005289         0.004627        0.004897
# 11       1.680038      0.033852         0.021145        0.002029
# 12       0.061909      0.003981         0.004528        0.004607
# 13       0.585298      0.009483         0.022048        0.003057
# 14       0.061929      0.001760         0.007218        0.003122
# 15       0.540874      0.069614         0.016062        0.004917
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4     friedman_mse               sqrt                 10
# 5     friedman_mse               sqrt                100
# 6     friedman_mse               log2                 10
# 7     friedman_mse               log2                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
# 12         poisson               sqrt                 10
# 13         poisson               sqrt                100
# 14         poisson               log2                 10
# 15         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.833717
# 1   {'criterion': 'squared_error', 'max_features':...           0.856572
# 2   {'criterion': 'squared_error', 'max_features':...           0.851692
# 3   {'criterion': 'squared_error', 'max_features':...           0.857410
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.858948
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.857503
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.856939
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.852281
# 8   {'criterion': 'absolute_error', 'max_features'...           0.828718
# 9   {'criterion': 'absolute_error', 'max_features'...           0.853614
# 10  {'criterion': 'absolute_error', 'max_features'...           0.848652
# 11  {'criterion': 'absolute_error', 'max_features'...           0.856202
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.828186
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.861518
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.837436
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.858521
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.779215           0.852860           0.804555
# 1            0.776200           0.859002           0.831551
# 2            0.754633           0.837234           0.810519
# 3            0.776707           0.860299           0.830498
# 4            0.747006           0.847900           0.803028
# 5            0.776405           0.862936           0.823049
# 6            0.774105           0.833943           0.812037
# 7            0.781972           0.855696           0.831673
# 8            0.760917           0.833939           0.808726
# 9            0.780081           0.858069           0.827701
# 10           0.771604           0.833141           0.808258
# 11           0.786032           0.857864           0.826587
# 12           0.762320           0.848887           0.812560
# 13           0.784368           0.861725           0.827880
# 14           0.761199           0.856159           0.810003
# 15           0.780062           0.862022           0.829602
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.833606         0.820791        0.025892                9
# 1            0.840961         0.832857        0.030078                4
# 2            0.826222         0.816060        0.033542               13
# 3            0.837319         0.832447        0.030111                6
# 4            0.834907         0.818358        0.040300               11
# 5            0.841387         0.832256        0.031197                7
# 6            0.812397         0.817884        0.027437               12
# 7            0.841373         0.832599        0.026690                5
# 8            0.833030         0.813066        0.027632               16
# 9            0.841372         0.832167        0.028102                8
# 10           0.833717         0.819075        0.027046               10
# 11           0.840521         0.833441        0.026303                3
# 12           0.826369         0.815665        0.029087               14
# 13           0.841831         0.835465        0.028556                1
# 14           0.805508         0.814061        0.032257               15
# 15           0.841917         0.834425        0.029587                2

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 43
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
Future_prediction
print("Future_prediction={}".format(Future_prediction))
# Out:
# Future_prediction=[44066.8007032]
# C:\Users\LENOVO\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
